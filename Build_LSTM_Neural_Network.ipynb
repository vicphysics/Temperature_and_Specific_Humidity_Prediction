# %%
import os
import csv
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def mape (y_true, y_pred):
    return 100*K.mean(K.sqrt(K.square(y_true - y_pred))/y_true)

def pearson (y_true, y_pred):
    return (K.square(K.mean((y_true - K.mean(y_true))*(y_pred - K.mean(y_pred)))))/(K.mean(K.square(y_true - K.mean(y_true)))*K.mean(K.square(y_pred - K.mean(y_pred))))

# define base mode
def baseline_model():
    
    # create model (design network)
    model = Sequential()
    #model.add(LSTM(n_neurons, batch_input_shape=(n_batch, 1, 32), stateful=True))
    #model.add(LSTM(n_neurons, batch_input_shape=(n_batch, 1, 32), stateful=True))
    model.add(Dense(16, input_dim=16, activation='relu'))
    model.add(Dense(8), activation='relu')
    model.add(Dense(1))
    #compile model
    model.compile(loss=rmse, optimizer='adam', metrics=['accuracy', 'mae', rmse, mape, pearson])
    # fit network
    #for i in range(nb_epoch):
    #    model.fit(X, y, epochs=1, batch_size=n_batch, verbose=0, shuffle=False)
    #    model.reset_states()
    return model

# Main

# Get the current working directory 
current_directory = os.getcwd() 

# Print the current working directory 
print(current_directory)

# Define the directory containing the files 
path = current_directory+"\\Modeling\\"
print(path)

filename = path + 'Final_Monthly_Dataset.csv'

#Load dataset
df = pandas.read_csv(filename)
df = df.rename(columns={'Unnamed: 0' : 'indices'})

#Remove unused columns
df = df.drop(['Day', 'vapor_pressure'], axis=1)

# Round numbers in columns to reasonable precision
df['temperatures'] = np.round(df['temperatures'], 2)
df['slp'] = np.round(df['slp'], 2)
df['wet_bulb_temperature'] = np.round(df['wet_bulb_temperature'], 2)
df['specific_humidity'] = np.round(df['specific_humidity'], 2)
df['GHI'] = np.round(df['GHI'], 2)
df['PRCP'] = np.round(df['PRCP'], 2)
df['SNDP'] = np.round(df['SNDP'], 2)
df['latitude'] = np.round(df['latitude'], 2)
df['longitude'] = np.round(df['longitude'], 2)
df['elevation'] = np.round(df['elevation'], 2)
df['solar_activity'] = np.round(df['solar_activity'], 2)
df['ONI'] = np.round(df['ONI'], 2)
df['water'] = np.round(df['water'], 0)
df['region'] = np.round(df['region'], 0)
df['Year'] = np.round(df['Year'], 0)
df['Month'] = np.round(df['Month'], 0)

print(df)

#dataframe.reset_index()
dataset = df.values


# split into input (X) and output (Y) variables
X = dataset[:,4:20]
Y = dataset[:,3]


print(dataset)
print(X, Y)

#Set values for model parameters
time_steps = 180
n_features = 15
LSTM1_units = 32
LSTM2_units = 32
Dense_layer1_units = 16
Dense_layer2_units = 8
Dense_layer3_units = 1

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=100, batch_size=5, verbose=0)
kfold = KFold(n_splits=10, random_state=seed, shuffle=True)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Baseline: %.2f (%.2f) RMSE" % (results.mean(), results.std()))
# Out:
# C:\Users\User
# C:\Users\User\Modeling\
#        indices        date  file_id  temperatures      slp  \
# 0            0  2006-01-31     6501         12.21  1018.53
# 1            1  2006-02-28     6501          8.17  1021.23
# 2            2  2006-03-31     6501         15.68  1018.97
# 3            3  2006-04-30     6501         22.46  1014.69
# 4            4  2006-05-31     6501         23.66  1014.24
# ...        ...         ...      ...           ...      ...
# 24057    24057  2024-07-31     9858         28.60  1013.97
# 24058    24058  2024-08-31     9858         29.11  1015.11
# 24059    24059  2024-09-30     9858         24.57  1014.39
# 24060    24060  2024-10-31     9858         21.16  1018.23
# 24061    24061  2024-11-30     9858         12.11  1015.40
#
#        wet_bulb_temperature  specific_humidity  water     GHI      WDSP  PRCP  \
# 0                      7.76               5.39    1.0  108.34  6.348387  0.23
# ...
