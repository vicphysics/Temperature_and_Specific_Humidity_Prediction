# %%
import os
import csv
import numpy as np
import pandas as pd
from tensorflow import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense, Activation
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from datetime import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from matplotlib import pyplot
from numpy import array
import keras.backend as K

# date-time parsing function for loading the dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def mape (y_true, y_pred):
    return 100*K.mean(K.sqrt(K.square(y_true - y_pred))/y_true)

def pearson (y_true, y_pred):
    return (K.square(K.mean((y_true - K.mean(y_true))*(y_pred - K.mean(y_pred)))))/(K.mean(K.square(y_true - K.mean(y_true)))*K.mean(K.square(y_pred - K.mean(y_pred))))
 
# convert time series into a supervised learning problem
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):

    n_vars = 1 if type(data) is list else data.shape[1]
    cols, names = list(), list()
    df = DataFrame(data)
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
    	cols.append(df.shift(i))
    	names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)

    #print("Agg:")
    agg.columns = names
    #print(type(agg))
    #print(agg)

    #print("Test column var1(t):")
    #print(agg.iloc[:, -588]) # Column containing response actual values (temperature) at time t

    return agg
 
# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)
 
# transform series into train and test sets for supervised learning
def prepare_data(data, n_test, n_lag, n_seq):

    #Prepare data for time series forecasting.
    
    #Parameters:
    #x (array-like): Input features.
    #y (array-like): Target values.
    #n_test (int): Number of test samples.
    #n_lag (int): Number of lag observations.
    #n_seq (int): Number of sequence observations.
    
    #Returns:
    #tuple: Training and test datasets.

    #print("Prepare data input (difference input)")
    #print(data.shape)
    #print(data)

    n_vars = 1 if type(data) is list else data.shape[1]

	# transform data to be stationary
    diff_series = difference(data, 1)
    diff_values = []
    for i in range(len(diff_series)):
        diff_values_row = []
        for j in range(len(diff_series[0])):
            diff_values_row.append(diff_series[i][j])
        diff_values.append(diff_values_row)
    #print("Diff Series:")
    #print(diff_series.shape)
    #print(diff_series)
    #print("Diff_Values:")
    #print(len(diff_values))
    #print(diff_values)
    
    # split into train and test sets
    train_values, test_values = diff_values[0:-n_test], diff_values[-n_test:]
    
    #print(train_values)
    
    # rescale values to 0, 1
    scaler_all_features =  MinMaxScaler(feature_range=(0, 1))
    scaler =  MinMaxScaler(feature_range=(0, 1))
    train_scaled_values = scaler_all_features.fit_transform(train_values)
    response_train_values = []
    for i in range(len(train_values)):
        response_train_values.append(train_values[i][0]) # Uses first column (temperatures) as response variable
    response_train_values = np.array(response_train_values)
    response_train_values = response_train_values.reshape(len(response_train_values), 1)
    #response_train_values = response_train_values.reshape(-1, 1)
    #print("Response:")
    #print(response_train_values)
    # Fit the scaler for just the response variable for use later when forecasting
    response_scaled_values = scaler.fit_transform(response_train_values) 
    #print("Scaled values before reshape:")
    #print(train_scaled_values.shape)
    #print(train_scaled_values)
    test_scaled_values = scaler_all_features.transform(test_values)
    
    #scaled_values = scaled_values.reshape(len(scaled_values), 1)
    scaled_values = pd.concat([pd.DataFrame(train_scaled_values), pd.DataFrame(test_scaled_values)], axis=0)
    scaled_values = np.array(scaled_values)
    
    #print("Supervised input:")
    #print(scaled_values.shape)
    #print(scaled_values)
    
    # transform into supervised learning problem X, y
    supervised = series_to_supervised(scaled_values, n_lag, n_seq)
    print(type(supervised))
    supervised_values = supervised.values

    #print("Supervised going into train/test:")
    #print(len(supervised))
    #print(supervised)

    train, test = supervised_values[0:-n_test], supervised_values[-n_test:]

    # drop rows with NaN values
    train = pd.DataFrame(train)
    train.dropna(inplace=True)
    train = np.array(train)
    
    return scaler, scaler_all_features, train, test
 
# fit an LSTM network to training data
def fit_lstm(train, n_lag, n_seq, n_batch, nb_epoch):
    # reshape training into [samples, timesteps, features]
    X, y = train[:, 0:n_lag], train[:, n_lag:]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    print(y.shape[0])
    print(X.shape[0])
    print(X.shape[1])
    print(X.shape[2])
    # design network
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, batch_input_shape=(n_batch, X.shape[1], X.shape[2]), stateful=True))
    model.add(LSTM(64))
    model.add(Dense(y.shape[1], activation='relu'))
    #model.add(Dense(64, activation='relu'))
    #model.add(Dense(n_seq))
    model.compile(loss=rmse, optimizer='adam', metrics=['accuracy', 'mae', rmse, mape, pearson])
    # fit network
    #for i in range(nb_epoch):
    #    model.fit(X, y, epochs=200, batch_size=n_batch, verbose=1)
    #    model.reset_states()

    print(X.shape)
    print(y.shape)
    print(y)
    print(train.shape)
    
    model.fit(X, y, epochs=200, verbose=1)
    
    return model
 
# make one forecast with an LSTM,
def forecast_lstm(model, X, n_batch):
	# reshape input pattern to [samples, timesteps, features]
	X = X.reshape(1, 1, len(X))
	# make forecast
	forecast = model.predict(X, batch_size=n_batch)
	# convert to array
	return [x for x in forecast[0, :]]
 
# evaluate the persistence model
def make_forecasts(model, n_batch, train, test, n_lag, n_seq):
	forecasts = list()
	for i in range(len(test)):
		X, y = test[i, 0:n_lag], test[i, n_lag:]
		# make forecast
		forecast = forecast_lstm(model, X, n_batch)
		# store the forecast
		forecasts.append(forecast)
	return forecasts
 
# invert differenced forecast
def inverse_difference(last_ob, forecast):
	# invert first forecast
	inverted = list()
	inverted.append(forecast[0] + last_ob)
	# propagate difference forecast using inverted first value
	for i in range(1, len(forecast)):
		inverted.append(forecast[i] + inverted[i-1])
	return inverted
 
# inverse data transform on forecasts
def inverse_transform(series, forecasts, scaler, n_test):
    inverted = list()
    for i in range(len(forecasts)):
        # create array from forecast
        forecast = array(forecasts[i])
        forecast = forecast.reshape(1, len(forecast))
        # invert scaling
        inv_scale = scaler.inverse_transform(forecast)
        inv_scale = inv_scale[0, :]
        # invert differencing
        index = len(series) - n_test + i - 1
        last_ob = series.values[index]
        inv_diff = inverse_difference(last_ob, inv_scale)
        # store
        inverted.append(inv_diff)
    return inverted
 
# evaluate the RMSE for each forecast time step
def evaluate_forecasts(test, forecasts, n_lag, n_seq):
    print(test)
    for i in range(n_seq):
        actual = [row[i] for row in test]
        predicted = [forecast[i] for forecast in forecasts]
        rmse = sqrt(mean_squared_error(actual, predicted))
        print('t+%d RMSE: %f' % ((i+1), rmse))
 
# plot the forecasts in the context of the original dataset
def plot_forecasts(series, forecasts, n_test):
	# plot the entire dataset in blue
	pyplot.plot(series.values)
	# plot the forecasts in red
	for i in range(len(forecasts)):
		off_s = len(series) - n_test + i - 1
		off_e = off_s + len(forecasts[i]) + 1
		xaxis = [x for x in range(off_s, off_e)]
		yaxis = [series.values[off_s]] + forecasts[i]
		pyplot.plot(xaxis, yaxis, color='red')
	xlim = [0, 40]
    # show the plot
	pyplot.show()


# Get the current working directory 
current_directory = os.getcwd() 

# Print the current working directory 
print(current_directory)

# Define the directory containing the files 
path = current_directory+"\\Modeling\\"
print(path)

filename = path + 'Final_Monthly_Dataset.csv'

# load dataset
df = read_csv(filename, header=0, parse_dates=[0], index_col=0, date_format='%Y-%m')


df = df.rename(columns={'Unnamed: 0' : 'indices'})

#Remove unused columns
df = df.drop(['Day', 'vapor_pressure'], axis=1)

# Round numbers in columns to reasonable precision
df['temperatures'] = np.round(df['temperatures'], 2)
df['slp'] = np.round(df['slp'], 2)
df['wet_bulb_temperature'] = np.round(df['wet_bulb_temperature'], 2)
df['specific_humidity'] = np.round(df['specific_humidity'], 2)
df['GHI'] = np.round(df['GHI'], 2)
df['PRCP'] = np.round(df['PRCP'], 2)
df['SNDP'] = np.round(df['SNDP'], 2)
df['solar_activity'] = np.round(df['solar_activity'], 2)
df['ONI'] = np.round(df['ONI'], 2)
df['water'] = np.round(df['water'], 0)
df['region'] = np.round(df['region'], 0)

df_trimmed = df[df['file_id']==6501]
df_trimmed = df_trimmed.drop(['Year', 'Month', 'file_id', 'date', 'latitude', 'longitude', 'elevation'], axis=1)

print(df_trimmed)

dataset = df_trimmed.values

#print(dataset)

series = pd.Series(dataset[:, 0]) # Using first column (temperatures)

#print(series)

# configure
n_lag = 130
n_seq = 10
n_test = 10
n_epochs = 100
n_batch = 1

# prepare data
scaler, scaler_all_features, train, test = prepare_data(dataset, n_test, n_lag, n_seq)

print("Train:")
print(np.array(train).shape)
print(train)
print("Test:")
print(np.array(test).shape)
print(test)

# fit model
model = fit_lstm(train, n_lag, n_seq, n_batch, n_epochs)

# make forecasts
forecasts = make_forecasts(model, n_batch, train, test, n_lag, n_seq)

# inverse transform forecasts and test
forecasts = inverse_transform(series, forecasts, scaler, n_test+2)

# evaluate forecasts
evaluate_forecasts(test, forecasts, n_lag, n_seq)

# plot forecasts
plot_forecasts(series, forecasts, n_test+2)

model.summary()
# Out:
# C:\Users\User
# C:\Users\User\Modeling\
#      temperatures      slp  wet_bulb_temperature  specific_humidity  water  \
# 0           12.21  1018.53                  7.76               5.39    1.0
# 1            8.17  1021.23                  4.33               4.30    1.0
# 2           15.68  1018.97                 10.49               6.51    1.0
# 3           22.46  1014.69                 16.98              10.21    1.0
# 4           23.66  1014.24                 18.68              11.74    1.0
# ..            ...      ...                   ...                ...    ...
# 222         27.66  1016.01                 23.90              17.03    1.0
# 223         28.00  1016.53                 22.80              15.20    1.0
# 224         23.86  1013.56                 20.33              13.73    1.0
# 225         20.59  1020.43                 14.60               8.35    1.0
# 226         15.82  1017.05                 13.00               9.05    1.0
#
#         GHI      WDSP  PRCP  SNDP  region  solar_activity   ONI
# 0    108.34  6.348387  0.23   0.0     4.0           20.90 -0.91
# 1    126.00  4.871429  0.17   0.0     4.0            5.71 -0.67
# 2    180.94  6.396774  0.17   0.0     4.0           17.29 -0.71
# 3    241.31  5.590000  0.11   0.0     4.0           50.27 -0.32
# 4    260.04  4.967742  0.11   0.0     4.0           37.23 -0.09
# ..      ...       ...   ...   ...     ...             ...   ...
# 222     NaN  3.596774  0.13   0.0     4.0          196.55  0.05
# 223     NaN  3.306452  0.03   0.0     4.0          215.52 -0.11
# 224     NaN  3.570000  0.15   0.0     4.0          141.37 -0.25
# 225     NaN  3.474194  0.00   0.0     4.0          166.39 -0.26
# 226     NaN  4.653333  0.17   0.0     4.0          152.47 -0.19
#
# [227 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# Train:
# (40, 1680)
# [[0.27944683 0.65755297 0.31370558 ... 0.         0.54233152 0.34645669]
#  [0.83023367 0.31852358 0.80050761 ... 0.         0.15158626 0.45669291]
#  [0.79542203 0.18045113 0.81725888 ... 0.         0.36765534 0.24409449]
#  ...
#  [0.59179781 0.28844839 0.63654822 ... 0.         0.56983293 0.22834646]
#  [0.66285169 0.22556391 0.65279188 ... 0.         0.62455416 0.42519685]
#  [0.67429661 0.44360902 0.77005076 ... 0.         0.33095551 0.77165354]]
# Test:
# (10, 1680)
# [[0.7520267  0.28024607 0.80203046 ... 0.         0.30730242 0.61417323]
#  [0.69194087 0.45249487 0.7177665  ...        nan        nan        nan]
#  [0.71769194 0.35269993 0.73604061 ...        nan        nan        nan]
#  ...
#  [0.07439199 0.88243336 0.07715736 ...        nan        nan        nan]
#  [0.32522651 0.34996582 0.35431472 ...        nan        nan        nan]
#  [0.36385312 0.49145591 0.2857868  ...        nan        nan        nan]]
# 40
# 40
# 1
# 130
# (40, 1, 130)
# (40, 1550)
# [[0.31237094 0.67716535 0.3743443  ... 0.         0.54233152 0.34645669]
#  [0.50309743 0.21259843 0.49880782 ... 0.         0.15158626 0.45669291]
#  [0.33630561 0.11023622 0.93276109 ... 0.         0.36765534 0.24409449]
#  ...
#  [0.46733621 0.38582677 0.47257988 ... 0.         0.56983293 0.22834646]
#  [0.5229022  0.35433071 0.84263233 ... 0.         0.62455416 0.42519685]
#  [0.39543833 0.28346457 0.80925131 ... 0.         0.33095551 0.77165354]]
# (40, 1680)
# Epoch 1/200
# 2/2 [==============================] - 4s 6ms/step - loss: 0.4468 - accuracy: 0.0000e+00 - mae: 0.3590 - rmse: 0.4464 - mape: nan - pearson: 0.0018
# Epoch 2/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4429 - accuracy: 0.0000e+00 - mae: 0.3558 - rmse: 0.4424 - mape: nan - pearson: 0.0215
# Epoch 3/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.0000e+00 - mae: 0.3506 - rmse: 0.4358 - mape: nan - pearson: 0.0495
# Epoch 4/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4284 - accuracy: 0.0000e+00 - mae: 0.3425 - rmse: 0.4268 - mape: nan - pearson: 0.0776
# Epoch 5/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4163 - accuracy: 0.0000e+00 - mae: 0.3306 - rmse: 0.4140 - mape: nan - pearson: 0.0989
# Epoch 6/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4019 - accuracy: 0.0000e+00 - mae: 0.3158 - rmse: 0.3997 - mape: nan - pearson: 0.1202
# Epoch 7/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3839 - accuracy: 0.0000e+00 - mae: 0.2967 - rmse: 0.3812 - mape: nan - pearson: 0.1336
# Epoch 8/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3652 - accuracy: 0
200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3074 - mape: nan - pearson: 0.1771
# Epoch 107/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1792
# Epoch 108/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1796
# Epoch 109/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1793
# Epoch 110/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1793
# Epoch 111/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3065 - mape: nan - pearson: 0.1810
# Epoch 112/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1795
# Epoch 113/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3070 - mape: nan - pearson: 0.1782
# Epoch 114/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1783
# Epoch 115/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1786
# Epoch 116/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3070 - mape: nan - pearson: 0.1780
# Epoch 117/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3064 - mape: nan - pearson: 0.1801
# Epoch 118/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3066 - mape: nan - pearson: 0.1794
# Epoch 119/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1801
# Epoch 120/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3066 - mape: nan - pearson: 0.1801
# Epoch 121/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3064 - mape: nan - pearson: 0.1810
# Epoch 122/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3066 - mape: nan - pearson: 0.1806
# Epoch 123/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3072 - mape: nan - pearson: 0.1786
# Epoch 124/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1800
# Epoch 125/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1784
# Epoch 126/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3065 - mape: nan - pearson: 0.1808
# Epoch 127/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3067 - mape: nan - pearson: 0.1797
# Epoch 128/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3065 - mape: nan - pearson: 0.1804
# Epoch 129/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3067 - mape: nan - pearson: 0.1804
# Epoch 130/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3065 - mape: nan - pearson: 0.1811
# Epoch 131/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3066 - mape: nan - pearson: 0.1810
# Epoch 132/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1795
# Epoch 133/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1781
# Epoch 134/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3074 - mape: nan - pearson: 0.1773
# Epoch 135/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3067 - mape: nan - pearson: 0.1790
# Epoch 136/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3065 - mape: nan - pearson: 0.1805
# Epoch 137/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3070 - mape: nan - pearson: 0.1776
# Epoch 138/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3067 - mape: nan - pearson: 0.1795
# Epoch 139/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3072 - mape: nan - pearson: 0.1777
# Epoch 140/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3073 - mape: nan - pearson: 0.1775
# Epoch 141/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1776
# Epoch 142/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1807
# Epoch 143/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1791
# Epoch 144/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3065 - mape: nan - pearson: 0.1806
# Epoch 145/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1803
# Epoch 146/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3063 - mape: nan - pearson: 0.1824
# Epoch 147/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3066 - mape: nan - pearson: 0.1808
# Epoch 148/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1797
# Epoch 149/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1796
# Epoch 150/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1799
# Epoch 151/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3072 - mape: nan - pearson: 0.1781
# Epoch 152/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3061 - mape: nan - pearson: 0.1832
# Epoch 153/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3064 - mape: nan - pearson: 0.1818
# Epoch 154/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3066 - mape: nan - pearson: 0.1808
# Epoch 155/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1796
# Epoch 156/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3069 - mape: nan - pearson: 0.1795
# Epoch 157/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1788
# Epoch 158/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3061 - mape: nan - pearson: 0.1823
# Epoch 159/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3075 - mape: nan - pearson: 0.1765
# Epoch 160/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3072 - mape: nan - pearson: 0.1785
# Epoch 161/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1789
# Epoch 162/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1785
# Epoch 163/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3070 - mape: nan - pearson: 0.1786
# Epoch 164/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.0000e+00 - mae: 0.2087 - rmse: 0.3070 - mape: nan - pearson: 0.1784
# Epoch 165/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.0000e+00 - mae: 0.2087 - rmse: 0.3083 - mape: nan - pearson: 0.1740
# Epoch 166/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2086 - rmse: 0.3070 - mape: nan - pearson: 0.1782
# Epoch 167/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3070 - mape: nan - pearson: 0.1789
# Epoch 168/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1794
# Epoch 169/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3064 - mape: nan - pearson: 0.1810
# Epoch 170/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3066 - mape: nan - pearson: 0.1802
# Epoch 171/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3070 - mape: nan - pearson: 0.1790
# Epoch 172/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3071 - mape: nan - pearson: 0.1790
# Epoch 173/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3065 - mape: nan - pearson: 0.1811
# Epoch 174/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3066 - mape: nan - pearson: 0.1800
# Epoch 175/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3065 - mape: nan - pearson: 0.1811
# Epoch 176/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3072 - mape: nan - pearson: 0.1784
# Epoch 177/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3066 - mape: nan - pearson: 0.1804
# Epoch 178/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3071 - mape: nan - pearson: 0.1779
# Epoch 179/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3067 - mape: nan - pearson: 0.1792
# Epoch 180/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1803
# Epoch 181/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3066 - mape: nan - pearson: 0.1809
# Epoch 182/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3070 - mape: nan - pearson: 0.1799
# Epoch 183/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1804
# Epoch 184/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3068 - mape: nan - pearson: 0.1808
# Epoch 185/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3072 - mape: nan - pearson: 0.1789
# Epoch 186/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3076 - mape: nan - pearson: 0.1778
# Epoch 187/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3072 - mape: nan - pearson: 0.1785
# Epoch 188/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3064 - mape: nan - pearson: 0.1815
# Epoch 189/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3068 - mape: nan - pearson: 0.1793
# Epoch 190/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2085 - rmse: 0.3067 - mape: nan - pearson: 0.1803
# Epoch 191/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1799
# Epoch 192/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1796
# Epoch 193/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3073 - mape: nan - pearson: 0.1782
# Epoch 194/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1800
# Epoch 195/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1801
# Epoch 196/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3069 - mape: nan - pearson: 0.1793
# Epoch 197/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3070 - mape: nan - pearson: 0.1797
# Epoch 198/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2083 - rmse: 0.3064 - mape: nan - pearson: 0.1805
# Epoch 199/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3073 - mape: nan - pearson: 0.1776
# Epoch 200/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.0000e+00 - mae: 0.2084 - rmse: 0.3067 - mape: nan - pearson: 0.1798
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# [[0.7520267  0.28024607 0.80203046 ... 0.         0.30730242 0.61417323]
#  [0.69194087 0.45249487 0.7177665  ...        nan        nan        nan]
#  [0.71769194 0.35269993 0.73604061 ...        nan        nan        nan]
#  ...
#  [0.07439199 0.88243336 0.07715736 ...        nan        nan        nan]
#  [0.32522651 0.34996582 0.35431472 ...        nan        nan        nan]
#  [0.36385312 0.49145591 0.2857868  ...        nan        nan        nan]]
# t+1 RMSE: 11.140643
# t+2 RMSE: 12.314214
# t+3 RMSE: 12.459274
# t+4 RMSE: 12.385944
# t+5 RMSE: 12.801072
# t+6 RMSE: 12.080537
# t+7 RMSE: 7.761056
# t+8 RMSE: 13.348096
# t+9 RMSE: 21.660157
# t+10 RMSE: 31.093283
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_60 (LSTM)              (1, 1, 64)                49920
#
#  lstm_61 (LSTM)              (1, 64)                   33024
#
#  dense_49 (Dense)            (1, 1550)                 100750
#
# =================================================================
# Total params: 183,694
# Trainable params: 183,694
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(forecasts)
# Out:
# [[2.6800003814697266, 4.566877202987671, 4.524572672247887, 4.4240361097455025, 4.690832311213017, 4.13168841034174, -5.768311208188534, -15.668310826718807, -25.568310445249082, -35.468310063779356, -45.36830968230963, -55.2683093008399, -55.94354856580496, -65.84354818433523, -75.7435478028655, -76.0752394554019, -85.97523907393217, -95.87523869246245, -105.77523831099272, -105.66485015869141, -105.90680646717549, -104.91282236397267, -114.81282198250294, -124.71282160103321, -125.29521506845951, -123.84716266214848, -123.55517580926418, -123.49891373336315, -133.39891335189344, -143