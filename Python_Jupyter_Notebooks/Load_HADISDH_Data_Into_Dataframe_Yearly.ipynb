# %%
import csv
import os
import xarray as xr
import pandas as pd
import netCDF4 as nc
from datetime import datetime
from scipy import stats

# Get the current working directory 
current_directory = os.getcwd() 

# Print the current working directory 
print(current_directory)

# Define the directory containing the files 
path = current_directory+"\\Data\\HADISDH_Humidity\\NC_Files\\"
print(path)

# Create an empty list to hold the dataframes 
dataframes = [] 

# Create datetime object for comparison
datetime_str = '1/1/98 00:00:00'

# Convert string to datetime
datetime_object = datetime.strptime(datetime_str, '%d/%m/%y %H:%M:%S')

# Loop through all filenames in filenames_only.csv 
with open("filenames_only_yearly.csv", mode='r') as file: 
   csv_reader = csv.reader(file)
   for row in csv_reader:
      filename = row[0]
      # Open the NetCDF file
      file = path+filename
      ds = xr.open_dataset(file)
      # Convert the dataset to a DataFrame
      df = ds.to_dataframe().reset_index()
      df_filtered = df[df['time'] >= datetime_object] # Remove data older than January 1, 2006
      df_filtered.set_index('time', inplace = True)
      dataframes.append(df_filtered)

# Concatenate all Dataframes
combined_df = pd.concat(dataframes, ignore_index=False)

# Now combined_df contains all the data from NC files
print(combined_df)

# Display the dataframe
print(combined_df.head())
# Out:
# C:\Users\User
# C:\Users\User\Data\HADISDH_Humidity\NC_Files\
#                      coordinate_length  longitude  latitude  elevation  \
# time
# 1998-01-01 00:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 01:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 02:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 03:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 04:00:00                  0    -86.467    30.393        5.4
# ...                                ...        ...       ...        ...
# 2024-11-30 17:00:00                  0   -119.261    45.826      195.1
# 2024-11-30 18:00:00                  0   -119.261    45.826      195.1
# 2024-11-30 19:00:00                  0   -119.261    45.826      195.1
# 2024-11-30 20:00:00                  0   -119.261    45.826      195.1
# 2024-11-30 21:00:00                  0   -119.261    45.826      195.1
#
#                           station_id  temperatures  dewpoints          slp  \
# time
# 1998-01-01 00:00:00  b'777777777777'      8.000000  -1.000000  1031.800003
# 1998-01-01 01:00:00  b'777777777777'      8.000000  -1.000000  1032.599998
# 1998-01-01 02:00:00  b'777777777777'      8.000000  -1.000000  1033.199997
# 1998-01-01 03:00:00  b'777777777777'      7.000000  -1.000000  1034.099998
# 1998-01-01 04:00:00  b'777777777777'           NaN        NaN          NaN
# ...                              ...           ...        ...          ...
# 2024-11-30 17:00:00  b'777777777777'      1.099998  -1.099998  1027.300003
# 2024-11-30 18:00:00  b'777777777777'      1.099998  -0.599998  1027.400002
# 2024-11-30 19:00:00  b'777777777777'      1.699997  -1.099998  1027.400002
# 2024-11-30 20:00:00  b'777777777777'      2.199997  -1.099998  1027.000000
# 2024-11-30 21:00:00  b'777777777777'      2.199997  -1.099998  1026.599998
#
#                      vapor_pressure  saturation_vapor_pressure  \
# time
# 1998-01-01 00:00:00        5.706459                  10.772789
# 1998-01-01 01:00:00        5.706482                  10.772820
# 1998-01-01 02:00:00        5.706490                  10.772842
# 1998-01-01 03:00:00        5.706505                  10.061279
# 1998-01-01 04:00:00             NaN                        NaN
# ...                             ...                        ...
# 2024-11-30 17:00:00        5.605339                   6.718300
# 2024-11-30 18:00:00        5.875198                   6.645622
# 2024-11-30 19:00:00        5.664223                   6.938171
# 2024-11-30 20:00:00        5.664215                   7.190613
# 2024-11-30 21:00:00        5.664207                   7.190598
#
#                      wet_bulb_temperature  specific_humidity  \
# time
# 1998-01-01 00:00:00              3.629646           3.449661
# 1998-01-01 01:00:00              3.629646           3.446991
# 1998-01-01 02:00:00              3.629646           3.444992
# 1998-01-01 03:00:00              3.059250           3.442009
# 1998-01-01 04:00:00                   NaN                NaN
# ...                                   ...                ...
# 2024-11-30 17:00:00             -0.358337           3.490479
# 2024-11-30 18:00:00              0.026810           3.658539
# 2024-11-30 19:00:00              0.084686           3.526688
# 2024-11-30 20:00:00              0.345848           3.527893
# 2024-11-30 21:00:00              0.345848           3.529266
#
#                      relative_humidity input_station_id
# time
# 1998-01-01 00:00:00          52.971077  b'722069-99999'
# 1998-01-01 01:00:00          52.971077  b'722069-99999'
# 1998-01-01 02:00:00          52.971077  b'722069-99999'
# 1998-01-01 03:00:00          56.717537  b'722069-99999'
# 1998-01-01 04:00:00                NaN  b'722069-99999'
# ...                                ...              ...
# 2024-11-30 17:00:00          83.433815  b'726883-04113'
# 2024-11-30 18:00:00          88.407074  b'726883-04113'
# 2024-11-30 19:00:00          81.638573  b'726883-04113'
# 2024-11-30 20:00:00          78.772423  b'726883-04113'
# 2024-11-30 21:00:00          78.772423  b'726883-04113'
#
# [5893053 rows x 14 columns]
#                      coordinate_length  longitude  latitude  elevation  \
# time
# 1998-01-01 00:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 01:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 02:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 03:00:00                  0    -86.467    30.393        5.4
# 1998-01-01 04:00:00                  0    -86.467    30.393        5.4
#
#                           station_id  temperatures  dewpoints          slp  \
# time
# 1998-01-01 00:00:00  b'777777777777'           8.0       -1.0  1031.800003
# 1998-01-01 01:00:00  b'777777777777'           8.0       -1.0  1032.599998
# 1998-01-01 02:00:00  b'777777777777'           8.0       -1.0  1033.199997
# 1998-01-01 03:00:00  b'777777777777'           7.0       -1.0  1034.099998
# 1998-01-01 04:00:00  b'777777777777'           NaN        NaN          NaN
#
#                      vapor_pressure  saturation_vapor_pressure  \
# time
# 1998-01-01 00:00:00        5.706459                  10.772789
# 1998-01-01 01:00:00        5.706482                  10.772820
# 1998-01-01 02:00:00        5.706490                  10.772842
# 1998-01-01 03:00:00        5.706505                  10.061279
# 1998-01-01 04:00:00             NaN                        NaN
#
#                      wet_bulb_temperature  specific_humidity  \
# time
# 1998-01-01 00:00:00              3.629646           3.449661
# 1998-01-01 01:00:00              3.629646           3.446991
# 1998-01-01 02:00:00              3.629646           3.444992
# 1998-01-01 03:00:00              3.059250           3.442009
# 1998-01-01 04:00:00                   NaN                NaN
#
#                      relative_humidity input_station_id
# time
# 1998-01-01 00:00:00          52.971077  b'722069-99999'
# 1998-01-01 01:00:00          52.971077  b'722069-99999'
# 1998-01-01 02:00:00          52.971077  b'722069-99999'
# 1998-01-01 03:00:00          56.717537  b'722069-99999'
# 1998-01-01 04:00:00                NaN  b'722069-99999'
